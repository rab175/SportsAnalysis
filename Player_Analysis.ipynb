# %% [markdown]
# # 2019 Player Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('season2019_test.csv')

df.head()
# Out:
#            name          id home team pos  defense_ast  defense_ffum  \
# 0    M.Trubisky  00-0033869   no  CHI  QB          NaN           NaN
# 1       M.Davis  00-0032063   no  CHI  RB          NaN           NaN
# 2  D.Montgomery  00-0035685   no  CHI  RB          NaN           NaN
# 3   C.Patterson  00-0030578   no  CHI  WR          NaN           NaN
# 4       T.Cohen  00-0033556   no  CHI  RB          NaN           NaN
#
#    defense_int  defense_sk  defense_tkl     ...       receiving_twopta  \
# 0          NaN         NaN          NaN     ...                    NaN
# 1          NaN         NaN          NaN     ...                    0.0
# 2          NaN         NaN          NaN     ...                    0.0
# 3          NaN         NaN          NaN     ...                    0.0
# 4          NaN         NaN          NaN     ...                    0.0
#
#    receiving_twoptm  receiving_yds  rushing_att  rushing_lng  rushing_lngtd  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'id', 'home', 'team', 'pos', 'defense_ast', 'defense_ffum',
#        'defense_int', 'defense_sk', 'defense_tkl', 'fumbles_lost',
#        'fumbles_rcv', 'fumbles_tot', 'fumbles_trcv', 'fumbles_yds',
#        'kicking_fga', 'kicking_fgm', 'kicking_fgyds', 'kicking_totpfg',
#        'kicking_xpa', 'kicking_xpb', 'kicking_xpmade', 'kicking_xpmissed',
#        'kicking_xptot', 'kickret_avg', 'kickret_lng', 'kickret_lngtd',
#        'kickret_ret', 'kickret_tds', 'passing_att', 'passing_cmp',
#        'passing_ints', 'passing_tds', 'passing_twopta', 'passing_twoptm',
#        'passing_yds', 'punting_avg', 'punting_i20', 'punting_lng',
#        'punting_pts', 'punting_yds', 'puntret_avg', 'puntret_lng',
#        'puntret_lngtd', 'puntret_ret', 'puntret_tds', 'receiving_lng',
#        'receiving_lngtd', 'receiving_rec', 'receiving_tds', 'receiving_twopta',
#        'receiving_twoptm', 'receiving_yds', 'rushing_att', 'rushing_lng',
# ...

# %%
df2 = pd.read_csv('season2010.csv')

df2.hea
