# %% [markdown]
# # 2019 Player Analysis

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('season2019_test.csv')

df.head()
# Out:
#            name          id home team pos  defense_ast  defense_ffum  \
# 0    M.Trubisky  00-0033869   no  CHI  QB          NaN           NaN
# 1       M.Davis  00-0032063   no  CHI  RB          NaN           NaN
# 2  D.Montgomery  00-0035685   no  CHI  RB          NaN           NaN
# 3   C.Patterson  00-0030578   no  CHI  WR          NaN           NaN
# 4       T.Cohen  00-0033556   no  CHI  RB          NaN           NaN
#
#    defense_int  defense_sk  defense_tkl     ...       receiving_twopta  \
# 0          NaN         NaN          NaN     ...                    NaN
# 1          NaN         NaN          NaN     ...                    0.0
# 2          NaN         NaN          NaN     ...                    0.0
# 3          NaN         NaN          NaN     ...                    0.0
# 4          NaN         NaN          NaN     ...                    0.0
#
#    receiving_twoptm  receiving_yds  rushing_att  rushing_lng  rushing_lngtd  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 60 columns):
# name                1615 non-null object
# id                  1615 non-null object
# home                1615 non-null object
# team                1615 non-null object
# pos                 1293 non-null object
# defense_ast         894 non-null float64
# defense_ffum        894 non-null float64
# defense_int         894 non-null float64
# defense_sk          894 non-null float64
# defense_tkl         894 non-null float64
# fumbles_lost        574 non-null float64
# fumbles_rcv         574 non-null float64
# fumbles_tot         574 non-null float64
# fumbles_trcv        574 non-null float64
# fumbles_yds         574 non-null float64
# kicking_fga         42 non-null float64
# kicking_fgm         42 non-null float64
# kicking_fgyds       42 non-null float64
# kicking_totpfg      42 non-null float64
# kicking_xpa         42 non-null float64
# ...

# %%
df.team.nunique()
# Out:
# 32

# %%
df[df['team'] == "NO"]
# Out:
#                    name          id home team  pos  defense_ast  defense_ffum  \
# 762             D.Brees  00-0020531   no   NO   QB          NaN           NaN
# 763            A.Kamara  00-0033906   no   NO   RB          NaN           NaN
# 764            L.Murray  00-0030513   no   NO   RB          NaN           NaN
# 765              T.Hill  00-0033357   no   NO   QB          NaN           NaN
# 766            M.Thomas  00-0032765   no   NO   WR          NaN           NaN
# 767              T.Ginn  00-0025396   no   NO  NaN          NaN           NaN
# 768              J.Cook  00-0027061   no   NO   TE          NaN           NaN
# 769             T.Smith  00-0034765   no   NO   WR          NaN           NaN
# 770              J.Hill  00-0030216   no   NO   TE          NaN           NaN
# 771              W.Lutz  00-0032569   no   NO    K          NaN           NaN
# 772          T.Morstead  00-0027114   no   NO    P          NaN           NaN
# ...

# %%
df2 = pd.read_csv('season2010.csv')

df2.head()
# Out:
#         name          id home team  pos  defense_ast  defense_ffum  \
# 0    D.Brees  00-0020531   no   NO   QB          NaN           NaN
# 1   P.Thomas  00-0024813   no   NO  NaN          NaN           NaN
# 2     R.Bush  00-0024217   no   NO  NaN          NaN           NaN
# 3  M.Colston  00-0024466   no   NO  NaN          NaN           NaN
# 4  R.Meachem  00-0025414   no   NO  NaN          NaN           NaN
#
#    defense_int  defense_sk  defense_tkl  fumbles_lost  fumbles_rcv  \
# 0          NaN         NaN          NaN           2.0          5.0
# 1          NaN         NaN          NaN           NaN          NaN
# 2          NaN         NaN          NaN           1.0          2.0
# 3          NaN         NaN          NaN           NaN          NaN
# 4          NaN         NaN          NaN           NaN          NaN
#
#    fumbles_tot  fumbles_trcv  fumbles_yds  kicking_fga  kicking_fgm  \
# 0          9.0           5.0          0.0          NaN          NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1545 entries, 0 to 1544
# Data columns (total 60 columns):
# name                1545 non-null object
# id                  1545 non-null object
# home                1545 non-null object
# team                1545 non-null object
# pos                 66 non-null object
# defense_ast         850 non-null float64
# defense_ffum        850 non-null float64
# defense_int         850 non-null float64
# defense_sk          850 non-null float64
# defense_tkl         850 non-null float64
# fumbles_lost        660 non-null float64
# fumbles_rcv         660 non-null float64
# fumbles_tot         660 non-null float64
# fumbles_trcv        660 non-null float64
# fumbles_yds         660 non-null float64
# kicking_fga         43 non-null float64
# kicking_fgm         43 non-null float64
# kicking_fgyds       43 non-null float64
# kicking_totpfg      43 non-null float64
# kicking_xpa         43 non-null float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
top_pass_yd_2010 = df2[df2['pos'] == 'QB'].sort_values(by='passing_yds',ascending=False)[:10]

# %%
top_pass_yd_2010[['name','passing_yds']]
# Out:
#                   name  passing_yds
# 828           P.Rivers       4710.0
# 0              D.Brees       4620.0
# 216           M.Schaub       4369.0
# 623          A.Rodgers       3922.0
# 163            T.Brady       3900.0
# 569             M.Ryan       3705.0
# 137            C.Henne       3298.0
# 1210  B.Roethlisberger       3200.0
# 1024     R.Fitzpatrick       2992.0
# 678            A.Smith       2370.0

# %%
fig = plt.figure(figsize=(10,8))

plt.bar(x=top_pass_yd_2010.name, height=top_pass_yd_2010.passing_yds)
plt.xticks(rotation=45);
